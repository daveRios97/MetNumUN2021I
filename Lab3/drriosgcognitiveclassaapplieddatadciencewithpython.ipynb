# %% [markdown]
# ### **Certificaciones Curso "Applied Data Science With Python"** ##

# %% [markdown]
# Linked In
#
# https://www.linkedin.com/in/david-rios-956119205/

# %% [markdown]
# <img src="https://raw.githubusercontent.com/drriosg/AlgorithmsUN2021I/master/Lab3/drriosgLinkedInCertificates.jpg">
